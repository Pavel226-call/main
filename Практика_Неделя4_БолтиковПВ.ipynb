# %% [markdown]
# <a href="https://colab.research.google.com/github/Pavel226-call/main/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0_%D0%9D%D0%B5%D0%B4%D0%B5%D0%BB%D1%8F4_%D0%91%D0%BE%D0%BB%D1%82%D0%B8%D0%BA%D0%BE%D0%B2%D0%9F%D0%92.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Задача 1

# %%
a=[]
while True:
  b=int(input())
  if b==0:
    break
  if b>2 and b<5:
    a.append(b)
  else:
    print("")
print(a)
# Out:
# 2
#
# 3
# 4
# 0
# [3, 4]
