# %% [markdown]
# <a href="https://colab.research.google.com/github/Pavel226-call/main/blob/main/%D0%91%D0%BE%D0%BB%D1%82%D0%B8%D0%BA%D0%BE%D0%B2_%D0%91%D0%98%D0%9A_24_%D0%98%D0%921_%D0%BF%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Задача 1

# %%
inp = []
dict1 = dict()


while True:
  inp1 = int(input("Введите 0 для завершения операции: "))
  if inp1 == 0:
    break
  inp.append(inp1)

for i in set(inp):
  dict1.update({ i: inp.count(i)})

print(dict1)
print(set(inp))
# Out:
# Введите 0 для завершения операции: 1
# Введите 0 для завершения операции: 3
# Введите 0 для завершения операции: 5
# Введите 0 для завершения операции: 25
# Введите 0 для завершения операции: 45
# Введите 0 для завершения операции: 55
# Введите 0 для завершения операции: 10
# Введите 0 для завершения операции: 0
# {1: 1, 3: 1, 5: 1, 10: 1, 45: 1, 55: 1, 25: 1}
# {1, 3, 5, 10, 45, 55, 25}

# %% [markdown]
# Задача 2

# %%
def main():
    phone_book = {}  # Словарь для хранения записей телефонной книги

    while True:
        command = input("Введите команду (add/who/exit): ")

        if command == 'add':
            add_contact(phone_book)
        elif command == 'who':
            find_contact(phone_book)
        elif command == 'exit':
            print("Завершение работы.")
            break
        else:
            print("Неизвестная команда. Попробуйте снова.")

def add_contact(phone_book):
    name = input("Введите имя: ")
    number = input("Введите номер телефона: ")

    phone_book[name] = number
    print(f"Контакт '{name}' добавлен с номером '{number}'.")

def find_contact(phone_book):
    name = input("Введите имя для поиска: ")

    if name in phone_book:
        print(f"Номер телефона для '{name}': {phone_book[name]}.")
    else:
        print(f"Контакт с именем '{name}' не найден.")

if __name__ == "__main__":
    main()
# Out:
# Введите команду (add/who/exit): add
# Введите имя: Пашка промокашка
# Введите номер телефона: 880005553535
# Контакт 'Пашка промокашка' добавлен с номером '880005553535'.
# Введите команду (add/who/exit): who
# Введите имя для поиска: Пашка промокашка
# Номер телефона для 'Пашка промокашка': 880005553535.
